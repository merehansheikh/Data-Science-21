# %%
import matplotlib.pyplot as plt

# Create a figure with 2 rows and 2 columns of subplots
plt.subplot(2, 1, 1)  # First subplot in the first row
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title('Subplot 1')

plt.subplot(2, 1, 2)  # Second subplot in the first row
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.title('Subplot 2')

# plt.subplot(2, 2, 3)  # First subplot in the second row
# plt.plot([1, 2, 3, 4], [10, 5, 10, 5])
# plt.title('Subplot 3')

# plt.subplot(2, 2, 4)  # Second subplot in the second row
# plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
# plt.title('Subplot 4')

plt.tight_layout()  # Adjust subplot parameters to give padding
plt.show()
